# %%
import pandas as pd
import numpy as np 
import math
from sklearn.preprocessing import OneHotEncoder
from copy import deepcopy
from src.utils import (
    load_config,
    load_data,
    split_input_output,
    split_train_test,
    serialize_data,
    deserialize_data
)

# %%
config = load_config()

# %%
config
# Out:
# {'directories': {'raw': 'data/raw',
#   'interim': 'data/interim',
#   'processed': 'data/processed'},
#  'files': {'dataset_name': 'credit_risk_dataset.csv',
#   'interim': {'X_train': 'X_train.pkl',
#    'y_train': 'y_train.pkl',
#    'X_valid': 'X_valid.pkl',
#    'y_valid': 'y_valid.pkl',
#    'X_test': 'X_test.pkl',
#    'y_test': 'y_test.pkl'}},
#  'path_raw_dir': '/home/amadeo/Pacmann/MLProcess/Mentoring/AMADEO_MLPROCESS/data/raw',
#  'path_interim_dir': '/home/amadeo/Pacmann/MLProcess/Mentoring/AMADEO_MLPROCESS/data/interim',
#  'path_processed_dir': '/home/amadeo/Pacmann/MLProcess/Mentoring/AMADEO_MLPROCESS/data/processed',
#  'path_raw_data': '/home/amadeo/Pacmann/MLProcess/Mentoring/AMADEO_MLPROCESS/data/raw/credit_risk_dataset.csv',
#  'path_X_train': '/home/amadeo/Pacmann/MLProcess/Mentoring/AMADEO_MLPROCESS/data/interim/X_train.pkl',
#  'path_y_train': '/home/amadeo/Pacmann/MLProcess/Mentoring/AMADEO_MLPROCESS/data/interim/y_train.pkl',
# ...

# %%
X_train = deserialize_data(config["path_X_train"])
y_train = deserialize_data(config["path_y_train"])
X_valid = deserialize_data(config["path_X_valid"])
y_valid = deserialize_data(config["path_X_valid"])
X_test = deserialize_data(config["path_X_test"])
y_test = deserialize_data(config["path_y_test"])

# %%
X_train.head()
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 15884          25         241875              MORTGAGE                4.0
# 15138          21          18000                  RENT                5.0
# 7474           25          53000              MORTGAGE               10.0
# 18212          28          16800                   OWN                NaN
# 6493           25          50000              MORTGAGE                2.0
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 15884   EDUCATION          A      16000           7.05                 0.07
# 15138    PERSONAL          B       1500          12.18                 0.08
# 7474      MEDICAL          B      16000          12.53                 0.30
# 18212     MEDICAL          C       5000          13.98                 0.30
# 6493      VENTURE          A      10000           7.90                 0.20
#
#       cb_person_default_on_file  cb_person_cred_hist_length
# ...
